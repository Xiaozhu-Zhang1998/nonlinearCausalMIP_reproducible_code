# %%
from causalchamber.datasets import Dataset

# %%
dataset = Dataset(name='lt_interventions_standard_v1', root='./')

variables = ['red', 'green', 'blue', 'current', 'ir_1', 'ir_2', 'ir_3', 'pol_1', 'pol_2']

experiments = [
    "uniform_reference"
]

df = dataset.get_experiment(experiments[0]).as_pandas_dataframe()[variables]

# %%
W[:,7] = W[:,7] - W[:,8]
W = W[:,0:8]
np.savetxt("W_0.csv", W, delimiter=',')
